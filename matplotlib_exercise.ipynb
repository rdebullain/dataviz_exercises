# %% [markdown]
# ## Matplotlib Assignment

# %%
# import pandas
import pandas as pd

# import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('company_sales_data.csv')

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# ### Task 1: Read the `total_profit` of all months and display it using a line plot.

# %%
plt.plot(df['month_number'], df['total_profit'])
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.title('Total Profit per Month')
plt.show()

# %% [markdown]
# ### Task 2: Read all the different product sales data and display it using a multiline plot.

# %%
plt.plot(df['month_number'], df['facecream'], label='Face cream Sales Data')
plt.plot(df['month_number'], df['facewash'], label='Face Wash Sales Data')
plt.plot(df['month_number'], df['toothpaste'], label='Toothpaste Sales Data')
plt.plot(df['month_number'], df['bathingsoap'], label='Bathing Soap Sales Data')
plt.plot(df['month_number'], df['shampoo'], label='Shampoo Sales Data')
plt.plot(df['month_number'], df['moisturizer'], label='Moisturizer Sales Data')

plt.xlabel('Month')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title('Sales data')
plt.xticks(df['month_number'])
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %% [markdown]
# ### Task 3: Read the `total_profit` of each month and display it using a histogram to find out which profit ranges are the most common.

# %%
plt.hist(df['total_profit'], bins=10, edgecolor='black')
plt.xlabel('Profit range')
plt.ylabel('Actual Profit')
plt.title('Profit data')
plt.show()
